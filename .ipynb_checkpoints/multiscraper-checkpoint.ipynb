# %%
from bs4 import BeautifulSoup
import urllib2

# %%
site = 'http://resepkoki.co/'

# %%
page = urllib2.urlopen(site)
soup = BeautifulSoup(page, 'html.parser')

# %%
main = soup.body.findAll('main')

# %%
for i in main.descendants:
    link = i.find('a', attrs={'href': True})
    print link.fi
    print
# Out:
# -1
#
# 9
#
# -1
#
# None
#
# None
#
# None
#
# 53
#
# -1
#
# 13
#
# None
#
# 6
#
# -1
#
# 10
#
# -1
#
# <a class="htop__link" href="http://www.kompas.com">Kompas.com</a>
#
# -1
#
# <a class="htop__link" href="http://www.kompas.com">Kompas.com</a>
#
# -1
#
# <a class="htop__link" href="http://www.kompas.com">Kompas.com</a>
#
# None
#
# 4
#
# -1
#
# <a class="htop__link" href="http://www.kompasiana.com" target="_blank">Kompasiana.com</a>
#
# None
#
# 4
#
# -1
#
# <a class="htop__link" href="http://www.kompaskarier.com" target="_blank">KompasKarier.com</a>
#
# None
#
# 4
#
# -1
#
# <a class="htop__link" href="http://www.gramedia.com" target="_blank">Gramedia.com</a>
#
# None
#
# 2
#
# -1
#
# <a class="htop__link" href="http://www.otomania.com" target="_blank">Otomania.com</a>
#
# None
#
# 4
#
# -1
#
# <a class="htop__link" href="http://www.juara.net" target="_blank">Juara.net</a>
#
# None
#
# 2
#
# -1
#
# -1
#
# -1
#
# ...
